# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns # for visualiation

from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

from sklearn.preprocessing import MinMaxScaler       # scaling data
from sklearn.neighbors import KNeighborsRegressor    # regressor

from sklearn.model_selection import GridSearchCV     # for grid search
from sklearn.pipeline import make_pipeline           # for making pipelines
from sklearn.preprocessing import LabelEncoder

# Assess the accuracy of predictions
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from IPython.display import HTML

import statsmodels.formula.api as smf # linear modeling
import warnings
warnings.filterwarnings('ignore')

shooting_and_sales_per_pop = pd.read_csv('./data/shootings_and_sales_per_pop.csv')
shooting_and_sales_per_pop.describe()
# Out:
#              year    population        admin       handgun       long_gun  \
# count  3120.00000  3.120000e+03  3120.000000  3.120000e+03    3120.000000
# mean   2015.00000  1.234632e+07    16.645833  2.256144e+04   18825.067949
# std       1.41444  4.380087e+07    91.761861  8.269515e+04   69769.322501
# min    2013.00000  5.793150e+05     0.000000  0.000000e+00       0.000000
# 25%    2014.00000  1.791128e+06     0.000000  2.858500e+03    3319.500000
# 50%    2015.00000  4.540492e+06     0.000000  7.403500e+03    6889.500000
# 75%    2016.00000  7.619730e+06     1.000000  1.583175e+04   13316.500000
# max    2017.00000  3.257192e+08  2435.000000  1.201747e+06  873335.000000
#
#              month      multiple          other        permit        totals  \
# count  3120.000000   3120.000000    3120.000000  3.120000e+03  3.120000e+03
# mean      6.500000    770.629167    1150.964744  2.807421e+04  7.511860e+04
# std       3.452606   2816.671262    4895.819297  1.097614e+05  2.740300e+05
# min       1.000000      0.000000       0.000000  0.000000e+00  2.300000e+01
# 25%       3.750000     39.000000      92.750000  7.417500e+02  9.946250e+03
# 50%       6.500000    216.000000     260.000000  3.730500e+03  2.410100e+04
# 75%       9.250000    568.250000     686.000000  1.454850e+04  4.603300e+04
# max      12.000000  34059.000000  111710.000000  1.251905e+06  3.308199e+06
#
#            ...          admin_pop  handgun_pop  long_gun_pop  multiple_pop  \
# count      ...        3120.000000  3120.000000   3120.000000   3120.000000
# mean       ...           0.146956   207.343773    197.680802      8.750927
# std        ...           0.674388   128.655670    134.232149      7.969797
# min        ...           0.000000     0.000000      0.000000      0.000000
# 25%        ...           0.000000   122.312728    100.330104      0.665113
# 50%        ...           0.000000   199.663178    169.009441      8.078368
# 75%        ...           0.015127   283.670948    265.227512     13.270332
# max        ...          21.304333   981.372780    817.178667     53.320128
#
#          other_pop   permit_pop   totals_pop   killed_pop  injured_pop  \
# count  3120.000000  3120.000000  3120.000000  3120.000000  3120.000000
# mean      9.630747   247.233412   706.617587     0.009569     0.035213
# std       8.589058   818.017984   871.717225     0.058632     0.278461
# min       0.000000     0.000000     3.480645     0.000000     0.000000
# 25%       3.832546    34.871661   394.290145     0.000000     0.000000
# 50%       8.303441   103.154570   585.693551     0.000000     0.000000
# 75%      13.493063   195.548924   800.671761     0.000000     0.028840
# max     198.310403  8545.843026  9380.854741     1.967953    14.709615
#
#        incidents_pop
# count    3120.000000
# mean        0.007799
# std         0.020178
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.009588
# max         0.307638
#
# [8 rows x 29 columns]

# %%
shooting_and_sales_per_pop.columns
# Out:
# Index(['year', 'state', 'population', 'admin', 'handgun', 'long_gun', 'month',
#        'multiple', 'other', 'permit', 'totals', 'killed', 'killed_max',
#        'injured', 'incidents', 'injured_max', 'affected_max',
#        'affected_over_10', 'killed_ave', 'injured_ave', 'admin_pop',
#        'handgun_pop', 'long_gun_pop', 'multiple_pop', 'other_pop',
#        'permit_pop', 'totals_pop', 'killed_pop', 'injured_pop',
#        'incidents_pop'],
#       dtype='object')

# %%
shooting_and_sales_per_pop = shooting_and_sales_per_pop[shooting_and_sales_per_pop.state != 'United States']

# %%
shooting_and_sales_per_pop.head()
# Out:
#     year    state  population  admin  handgun  long_gun  month  multiple  \
# 12  2013  Alabama   4827660.0    0.0  20186.0   30523.0     12     926.0
# 13  2013  Alabama   4827660.0    0.0  14646.0   22547.0     11     808.0
# 14  2013  Alabama   4827660.0    0.0  12230.0   15479.0     10     740.0
# 15  2013  Alabama   4827660.0    0.0  11406.0   13077.0      9     616.0
# 16  2013  Alabama   4827660.0    0.0  14310.0   13402.0      8     688.0
#
#     other   permit      ...        admin_pop  handgun_pop  long_gun_pop  \
# 12  738.0  21065.0      ...              0.0   418.132180    632.252478
# 13  508.0  15409.0      ...              0.0   303.376791    467.037861
# 14  461.0  18118.0      ...              0.0   253.331842    320.631527
# 15  566.0  16722.0      ...              0.0   236.263531    270.876574
# 16  350.0  17470.0      ...              0.0   296.416898    277.608614
#
#     multiple_pop  other_pop  permit_pop   totals_pop  killed_pop  injured_pop  \
# 12     19.181135  15.286909  436.339759  1602.722644    0.062142      0.10357
# 13     16.736887  10.522696  319.181550  1226.536252    0.000000      0.00000
# 14     15.328337   9.549140  375.295692  1067.183687    0.000000      0.00000
# 15     12.759805  11.724107  346.378991   958.290352    0.000000      0.00000
# 16     14.251211   7.249889  361.873040  1035.242747    0.000000      0.00000
#
#     incidents_pop
# 12       0.020714
# 13       0.000000
# 14       0.000000
# 15       0.000000
# 16       0.000000
#
# [5 rows x 30 columns]

# %%
shooting_and_sales_per_pop.tail()
# Out:
#       year    state  population  admin  handgun  long_gun  month  multiple  \
# 3115  2017  Wyoming    579315.0    5.0   1589.0    1578.0      5      91.0
# 3116  2017  Wyoming    579315.0    8.0   1633.0    1711.0      4      85.0
# 3117  2017  Wyoming    579315.0    6.0   2017.0    2038.0      3     124.0
# 3118  2017  Wyoming    579315.0    8.0   1839.0    1646.0      2     113.0
# 3119  2017  Wyoming    579315.0    0.0   1329.0    1433.0      1      73.0
#
#       other  permit      ...        admin_pop  handgun_pop  long_gun_pop  \
# 3115  101.0   435.0      ...         0.863088   274.289463    272.390668
# 3116  108.0   382.0      ...         1.380941   281.884640    295.348817
# 3117  134.0   534.0      ...         1.035706   348.169821    351.794792
# 3118  123.0   330.0      ...         1.380941   317.443878    284.128669
# 3119  109.0   449.0      ...         0.000000   229.408871    247.361108
#
#       multiple_pop  other_pop  permit_pop  totals_pop  killed_pop  \
# 3115     15.708207  17.434384   75.088682  712.565703         0.0
# 3116     14.672501  18.642707   65.939946  736.904793         0.0
# 3117     21.404590  23.130767   92.177831  917.462866         0.0
# 3118     19.505796  21.231972   56.963828  786.100826         0.0
# 3119     12.601089  18.815325   77.505330  639.548432         0.0
#
#       injured_pop  incidents_pop
# 3115          0.0            0.0
# 3116          0.0            0.0
# 3117          0.0            0.0
# 3118          0.0            0.0
# 3119          0.0            0.0
#
# [5 rows x 30 columns]

# %%
# Select optimal features for your model
corr = shooting_and_sales_per_pop.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

f, ax = plt.subplots(figsize=(11,9))
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# ## Statistical Model

# %%
g = sns.PairGrid(shooting_and_sales_per_pop,
                 x_vars=["killed_pop",'injured_pop', 'incidents_pop'],
                 y_vars=["totals_pop"],
                 aspect=.75, size=7)
g.map(plt.scatter)
plt.show()

# %%
lm = smf.ols(formula='permit ~ killed_pop', data=shooting_and_sales_per_pop).fit()
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 permit   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.4848
# Date:                Wed, 05 Dec 2018   Prob (F-statistic):              0.486
# Time:                        00:17:48   Log-Likelihood:                -36763.
# No. Observations:                3060   AIC:                         7.353e+04
# Df Residuals:                    3058   BIC:                         7.354e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.439e+04    731.604     19.673      0.000     1.3e+04    1.58e+04
# killed_pop -8495.2547   1.22e+04     -0.696      0.486   -3.24e+04    1.54e+04
# ==============================================================================
# Omnibus:                     3680.277   Durbin-Watson:                   0.373
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           335951.699
# Skew:                           6.532   Prob(JB):                         0.00
# Kurtosis:                      52.641   Cond. No.                         16.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
injured_lm = smf.ols(formula='permit ~ injured_pop', data=shooting_and_sales_per_pop).fit()
injured_lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 permit   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                  0.007973
# Date:                Wed, 05 Dec 2018   Prob (F-statistic):              0.929
# Time:                        00:17:50   Log-Likelihood:                -36763.
# No. Observations:                3060   AIC:                         7.353e+04
# Df Residuals:                    3058   BIC:                         7.354e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept    1.432e+04    727.924     19.672      0.000    1.29e+04    1.57e+04
# injured_pop  -229.4119   2569.308     -0.089      0.929   -5267.157    4808.333
# ==============================================================================
# Omnibus:                     3680.662   Durbin-Watson:                   0.373
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           336093.446
# Skew:                           6.533   Prob(JB):                         0.00
# Kurtosis:                      52.652   Cond. No.                         3.56
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
incident_lm = smf.ols(formula='permit ~ incidents_pop', data=shooting_and_sales_per_pop).fit()
incident_lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 permit   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.3096
# Date:                Wed, 05 Dec 2018   Prob (F-statistic):              0.578
# Time:                        00:17:53   Log-Likelihood:                -36763.
# No. Observations:                3060   AIC:                         7.353e+04
# Df Residuals:                    3058   BIC:                         7.354e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept      1.416e+04    773.270     18.309      0.000    1.26e+04    1.57e+04
# incidents_pop  1.973e+04   3.55e+04      0.556      0.578   -4.98e+04    8.93e+04
# ==============================================================================
# Omnibus:                     3680.666   Durbin-Watson:                   0.374
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           336085.000
# Skew:                           6.533   Prob(JB):                         0.00
# Kurtosis:                      52.651   Cond. No.                         49.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
shooting_and_sales_per_pop['simple_pred'] = lm.predict()

# %%
shooting_and_sales_per_pop['simple_pred_injured'] = injured_lm.predict()

# %%
shooting_and_sales_per_pop['simple_pred_incidents'] = incident_lm.predict()

# %%
shooting_and_sales_per_pop.plot('permit', 'simple_pred', kind="scatter")

# %%
shooting_and_sales_per_pop.plot('permit', 'simple_pred_injured', kind="scatter")

# %%
shooting_and_sales_per_pop.plot('permit', 'simple_pred_incidents', kind="scatter")

# %%
# What is the distrubution of the residuals?
shooting_and_sales_per_pop['simple_resids'] = shooting_and_sales_per_pop.permit - shooting_and_sales_per_pop.simple_pred
shooting_and_sales_per_pop.hist('simple_resids')
plt.show()

# %%
# What is the distrubution of the residuals?
shooting_and_sales_per_pop['simple_resids_injured'] = shooting_and_sales_per_pop.permit - shooting_and_sales_per_pop.simple_pred_injured
shooting_and_sales_per_pop.hist('simple_resids_injured')
plt.show()

# %%
# What is the distrubution of the residuals?
shooting_and_sales_per_pop['simple_resids_incidents'] = shooting_and_sales_per_pop.permit - shooting_and_sales_per_pop.simple_pred_incidents
shooting_and_sales_per_pop.hist('simple_resids_incidents')
plt.show()

# %%
full_model =  smf.ols(formula='permit ~ year + population + month + state + injured + incidents + injured_ave + killed_pop + injured_pop + incidents_pop', data=shooting_and_sales_per_pop).fit()
full_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 permit   R-squared:                       0.743
# Model:                            OLS   Adj. R-squared:                  0.738
# Method:                 Least Squares   F-statistic:                     146.8
# Date:                Wed, 05 Dec 2018   Prob (F-statistic):               0.00
# Time:                        00:20:42   Log-Likelihood:                -34686.
# No. Observations:                3060   AIC:                         6.949e+04
# Df Residuals:                    3000   BIC:                         6.985e+04
# Df Model:                          59
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# Intercept                     -3.184e+06    5.9e+05     -5.398      0.000   -4.34e+06   -2.03e+06
# state[T.Alaska]                1646.9036   1.28e+04      0.129      0.897   -2.34e+04    2.67e+04
# state[T.Arizona]              -2.162e+04   6919.299     -3.124      0.002   -3.52e+04   -8050.622
# state[T.Arkansas]             -4964.9002   6696.563     -0.741      0.459   -1.81e+04    8165.420
# state[T.California]           -1.188e+05   1.01e+05     -1.173      0.241   -3.17e+05    7.98e+04
# state[T.Colorado]             -1.525e+04   4126.506     -3.696      0.000   -2.33e+04   -7160.479
# state[T.Connecticut]          -1428.1709   5279.787     -0.270      0.787   -1.18e+04    8924.199
# state[T.Delaware]               600.3564   1.22e+04      0.049      0.961   -2.33e+04    2.45e+04
# state[T.District of Columbia]  1496.8356    1.3e+04      0.115      0.908    -2.4e+04     2.7e+04
# state[T.Florida]              -7.188e+04   4.59e+04     -1.566      0.117   -1.62e+05    1.81e+04
# state[T.Georgia]               -2.73e+04   1.63e+04     -1.674      0.094   -5.93e+04    4671.330
# state[T.Hawaii]                -555.6209   1.08e+04     -0.051      0.959   -2.18e+04    2.07e+04
# state[T.Idaho]                  431.5527   1.02e+04      0.042      0.966   -1.96e+04    2.04e+04
# state[T.Illinois]              7974.0932    2.4e+04      0.332      0.740   -3.91e+04     5.5e+04
# state[T.Indiana]               1.361e+04   6431.036      2.116      0.034     995.552    2.62e+04
# state[T.Iowa]                  -290.9064   6359.920     -0.046      0.964   -1.28e+04    1.22e+04
# state[T.Kansas]               -6812.4615   6880.681     -0.990      0.322   -2.03e+04    6678.869
# state[T.Kentucky]              2.196e+05   3943.579     55.676      0.000    2.12e+05    2.27e+05
# state[T.Louisiana]            -1.598e+04   3792.717     -4.213      0.000   -2.34e+04   -8540.647
# state[T.Maine]                -1091.2226   1.11e+04     -0.098      0.922   -2.29e+04    2.07e+04
# state[T.Maryland]             -2.172e+04   5051.354     -4.300      0.000   -3.16e+04   -1.18e+04
# state[T.Massachusetts]        -1.954e+04   6867.579     -2.845      0.004    -3.3e+04   -6074.823
# state[T.Michigan]              -2.44e+04   1.55e+04     -1.573      0.116   -5.48e+04    6024.052
# state[T.Minnesota]             3981.6229   4194.945      0.949      0.343   -4243.637    1.22e+04
# state[T.Mississippi]          -8121.3445   6676.407     -1.216      0.224   -2.12e+04    4969.454
# state[T.Missouri]             -1.867e+04   5209.316     -3.584      0.000   -2.89e+04   -8453.804
# state[T.Montana]               1312.3400   1.19e+04      0.110      0.913   -2.21e+04    2.47e+04
# state[T.Nebraska]                24.4985   9540.549      0.003      0.998   -1.87e+04    1.87e+04
# state[T.Nevada]               -6773.0317   6929.363     -0.977      0.328   -2.04e+04    6813.752
# state[T.New Hampshire]         1864.3792   1.11e+04      0.168      0.867   -1.99e+04    2.36e+04
# state[T.New Jersey]           -3.769e+04   1.28e+04     -2.954      0.003   -6.27e+04   -1.27e+04
# state[T.New Mexico]           -4073.1960   9019.389     -0.452      0.652   -2.18e+04    1.36e+04
# state[T.New York]              -8.53e+04   4.45e+04     -1.916      0.055   -1.73e+05    1979.800
# state[T.North Carolina]       -6618.5986   1.59e+04     -0.417      0.677   -3.78e+04    2.45e+04
# state[T.North Dakota]          2266.7892   1.28e+04      0.178      0.859   -2.27e+04    2.73e+04
# state[T.Ohio]                 -4.326e+04   2.04e+04     -2.121      0.034   -8.32e+04   -3265.856
# state[T.Oklahoma]             -1.369e+04   4687.721     -2.921      0.004   -2.29e+04   -4499.030
# state[T.Oregon]               -1.353e+04   4472.875     -3.025      0.003   -2.23e+04   -4759.095
# state[T.Pennsylvania]         -3.191e+04   2.39e+04     -1.338      0.181   -7.87e+04    1.49e+04
# state[T.Rhode Island]          -223.1955   1.19e+04     -0.019      0.985   -2.35e+04     2.3e+04
# state[T.South Carolina]       -8860.1083   3739.630     -2.369      0.018   -1.62e+04   -1527.610
# state[T.South Dakota]          1492.3350   1.24e+04      0.120      0.905   -2.29e+04    2.59e+04
# state[T.Tennessee]             -1.41e+04   6381.691     -2.210      0.027   -2.66e+04   -1589.283
# state[T.Texas]                 -9.98e+04   6.71e+04     -1.488      0.137   -2.31e+05    3.17e+04
# state[T.Utah]                  5297.9416   6662.111      0.795      0.427   -7764.826    1.84e+04
# state[T.Vermont]               1879.0374   1.31e+04      0.144      0.886   -2.38e+04    2.76e+04
# state[T.Virginia]             -3.433e+04   1.11e+04     -3.099      0.002    -5.6e+04   -1.26e+04
# state[T.Washington]           -1.515e+04   7842.728     -1.931      0.054   -3.05e+04     231.383
# state[T.West Virginia]        -2177.4336   9697.636     -0.225      0.822   -2.12e+04    1.68e+04
# state[T.Wisconsin]            -1.262e+04   4623.373     -2.730      0.006   -2.17e+04   -3558.787
# state[T.Wyoming]               2700.1316   1.32e+04      0.204      0.838   -2.32e+04    2.86e+04
# year                           1578.8201    295.957      5.335      0.000     998.522    2159.119
# population                        0.0048      0.003      1.603      0.109      -0.001       0.011
# month                          -326.0007    107.339     -3.037      0.002    -536.466    -115.535
# injured                         267.5204    295.166      0.906      0.365    -311.229     846.270
# incidents                     -2276.8178   1250.386     -1.821      0.069   -4728.519     174.884
# injured_ave                     404.9305    330.268      1.226      0.220    -242.645    1052.506
# killed_pop                    -1.353e+04   9173.610     -1.475      0.140   -3.15e+04    4458.962
# injured_pop                   -1.839e+04   9203.799     -1.998      0.046   -3.64e+04    -344.066
# incidents_pop                  9.532e+04    4.5e+04      2.118      0.034    7087.049    1.84e+05
# ==============================================================================
# Omnibus:                     2482.618   Durbin-Watson:                   0.777
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          3151736.498
# Skew:                           2.494   Prob(JB):                         0.00
# Kurtosis:                     160.145   Cond. No.                     1.53e+10
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.53e+10. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
shooting_and_sales_per_pop['mult_pred']=full_model.predict()
shooting_and_sales_per_pop.plot('permit', 'mult_pred', kind='scatter')
plt.plot(shooting_and_sales_per_pop.permit, shooting_and_sales_per_pop.permit, color='red')
plt.show()

# %%
shooting_and_sales_per_pop['mult_pred']=full_model.predict()
shooting_and_sales_per_pop.plot('permit_pop', 'mult_pred', kind='scatter')
plt.plot(shooting_and_sales_per_pop.permit, shooting_and_sales_per_pop.permit, color='red')
plt.show()

# %%
df_year = shooting_and_sales_per_pop['year'].value_counts()   # for weekofyear variable
year_df = pd.DataFrame({'Year':df_year.index, 'Count':df_year.values})
lm_year = smf.ols(formula= "Year ~ Count", data=year_df).fit().summary()
lm_year
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Year   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Tue, 04 Dec 2018   Prob (F-statistic):                nan
# Time:                        16:36:39   Log-Likelihood:                -8.8276
# No. Observations:                   5   AIC:                             19.66
# Df Residuals:                       4   BIC:                             19.26
# Df Model:                           0
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0054   1.89e-06   2849.640      0.000       0.005       0.005
# Count          3.2925      0.001   2849.640      0.000       3.289       3.296
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.100
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.352
# Skew:                           0.000   Prob(JB):                        0.839
# Kurtosis:                       1.700   Cond. No.                     2.57e+18
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.84e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
df_month = shooting_and_sales_per_pop['month'].value_counts()   # for weekofyear variable
month_df = pd.DataFrame({'Month':df_month.index, 'Count':df_month.values})
lm_month = smf.ols(formula= "Month ~ Count", data=month_df).fit().summary()
lm_month
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Month   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Tue, 04 Dec 2018   Prob (F-statistic):                nan
# Time:                        16:36:39   Log-Likelihood:                -31.895
# No. Observations:                  12   AIC:                             65.79
# Df Residuals:                      11   BIC:                             66.27
# Df Model:                           0
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   9.996e-05    1.6e-05      6.245      0.000    6.47e-05       0.000
# Count          0.0255      0.004      6.245      0.000       0.017       0.034
# ==============================================================================
# Omnibus:                        2.375   Durbin-Watson:                   1.126
# Prob(Omnibus):                  0.305   Jarque-Bera (JB):                0.740
# Skew:                           0.000   Prob(JB):                        0.691
# Kurtosis:                       1.783   Cond. No.                     2.45e+18
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.3e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
HTML('''<script type='text/javascript' src='https://10az.online.tableau.com/javascripts/api/viz_v1.js'></script><div class='tableauPlaceholder' style='width: 1000px; height: 650px;'><object class='tableauViz' width='1000' height='650' style='display:none;'><param name='host_url' value='https%3A%2F%2F10az.online.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='&#47;t&#47;kidusindex' /><param name='name' value='Permit_By_Month_Vis&#47;Sheet1' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='showAppBanner' value='false' /><param name='filter' value='iframeSizedToWindow=true' /></object></div>''')
# Out:
# <script type='text/javascript' src='https://10az.online.tableau.com/javascripts/api/viz_v1.js'></script><div class='tableauPlaceholder' style='width: 1000px; height: 709px;'><object class='tableauViz' width='1000' height='709' style='display:none;'><param name='host_url' value='https%3A%2F%2F10az.online.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='&#47;t&#47;kidusindex' /><param name='name' value='Permit_By_Month_Vis&#47;Sheet1' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='showAppBanner' value='false' /><param name='filter' value='iframeSizedToWindow=true' /></object></div>

# %% [markdown]
# ## Machine Learning Model
