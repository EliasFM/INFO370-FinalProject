# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns # for visualiation

# combined mass shooting data from 13-18
mass_shoot_13_18 = pd.read_csv('./data/mass_shooting_data_13_18.csv')
df= mass_shoot_13_18
df = df.drop(['Operations'], axis=1)

# %%
mass_shoot_13_18.head()
# Out:
#        Incident Date       State City Or County                     Address  \
# 0  December 31, 2013    New York       Brooklyn             60 Glenmore Ave
# 1  December 28, 2013     Alabama     Montgomery            954 Highland Ave
# 2  December 26, 2013   Louisiana        Slidell               2144 First St
# 3  December 26, 2013   Louisiana       Lockport                313 Tenth St
# 4  December 25, 2013  New Jersey      Irvington  Nye Avenue and 21st Street
#
#    # Killed  # Injured  Operations
# 0         0          6         NaN
# 1         3          5         NaN
# 2         2          6         NaN
# 3         3          3         NaN
# 4         3          2         NaN

# %%
df['# Casualties'] = df['# Killed'] + df['# Injured']
df.to_csv("./data/Mass_shooting_cleaned.csv", index=False)

df.head()
# Out:
#        Incident Date       State City Or County                     Address  \
# 0  December 31, 2013    New York       Brooklyn             60 Glenmore Ave
# 1  December 28, 2013     Alabama     Montgomery            954 Highland Ave
# 2  December 26, 2013   Louisiana        Slidell               2144 First St
# 3  December 26, 2013   Louisiana       Lockport                313 Tenth St
# 4  December 25, 2013  New Jersey      Irvington  Nye Avenue and 21st Street
#
#    # Killed  # Injured  # Casualties
# 0         0          6             6
# 1         3          5             8
# 2         2          6             8
# 3         3          3             6
# 4         3          2             5

# %%
sns.set(style="whitegrid")

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(6, 15))

# Plot the total crashes
sns.set_color_codes("pastel")
sns.barplot(x="# Casualties", y="State", data=df,
            label="Total Casualties", color="b")

# Plot the crashes where alcohol was involved
sns.set_color_codes("muted")
sns.barplot(x="# Killed", y="State", data=df,
            label="Killed", color="b")

# # Plot the crashes where alcohol was involved
# sns.set_color_codes("muted")
# sns.barplot(x="# Injured", y="State", data=df,
#             label="Injured", color="b")

# Add a legend and informative axis label
ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(xlim=(0, 70), ylabel="",
       xlabel="Mass shooting by state")
sns.despine(left=True, bottom=True)
# Out:
# /Users/kidussendeke/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# sns.set(style="darkgrid")

g = sns.FacetGrid(df, row="State", col="City Or County", margin_titles=True)
bins = np.linspace(0, 30, 10)
g.map(plt.hist, "# Casualties", color="steelblue", bins=bins)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-03111c82c75f> in <module>()
#       1 # sns.set(style="darkgrid")
#       2
# ----> 3 g = sns.FacetGrid(df, row="State", col="City Or County", margin_titles=True)
#       4 bins = np.linspace(0, 60, 13)
#       5 g.map(plt.hist, "# Casualties", color="steelblue", bins=bins)
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py in __init__(self, data, row, col, hue, col_wrap, sharex, sharey, height, aspect, palette, row_order, col_order, hue_order, hue_kws, dropna, legend_out, despine, margin_titles, xlim, ylim, subplot_kws, gridspec_kws, size)
#     309                     warnings.warn(msg.format(MPL_GRIDSPEC_VERSION))
#     310
# --> 311             fig, axes = plt.subplots(nrow, ncol, **kwargs)
#     312             self.axes = axes
#     313
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
#    1185     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1186                        squeeze=squeeze, subplot_kw=subplot_kw,
# -> 1187                        gridspec_kw=gridspec_kw)
#    1188     return fig, axs
#    1189
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in subplots(self, nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw)
#    1367                 subplot_kw["sharex"] = shared_with[sharex]
#    1368                 subplot_kw["sharey"] = shared_with[sharey]
# -> 1369                 axarr[row, col] = self.add_subplot(gs[row, col], **subplot_kw)
#    1370
#    1371         # turn off redundant tick labeling
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#    1255                     self._axstack.remove(ax)
#    1256
# -> 1257             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1258         self._axstack.add(key, a)
#    1259         self.sca(a)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_subplots.py in __init__(self, fig, *args, **kwargs)
#      75
#      76         # _axes_class is set in the subplot_class_factory
# ---> 77         self._axes_class.__init__(self, fig, self.figbox, **kwargs)
#      78         # add a layout box to this, for both the full axis, and the poss
#      79         # of the axis.  We need both because the axes may become smaller
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in __init__(self, fig, rect, facecolor, frameon, sharex, sharey, label, xscale, yscale, **kwargs)
#     509
#     510         # this call may differ for non-sep axes, e.g., polar
# --> 511         self._init_axis()
#     512         if facecolor is None:
#     513             facecolor = rcParams['axes.facecolor']
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in _init_axis(self)
#     620         self.spines['bottom'].register_axis(self.xaxis)
#     621         self.spines['top'].register_axis(self.xaxis)
# --> 622         self.yaxis = maxis.YAxis(self)
#     623         self.spines['left'].register_axis(self.yaxis)
#     624         self.spines['right'].register_axis(self.yaxis)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in __init__(self, axes, pickradius)
#     730         self._minor_tick_kw = dict()
#     731
# --> 732         self.cla()
#     733         self._set_scale('linear')
#     734
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in cla(self)
#     804         self.label.set_text('')  # self.set_label_text would change isDefault_
#     805
# --> 806         self._set_scale('linear')
#     807
#     808         # Clear the callback registry for this axis, or it may "leak"
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in _set_scale(self, value, **kwargs)
#     770     def _set_scale(self, value, **kwargs):
#     771         self._scale = mscale.scale_factory(value, self, **kwargs)
# --> 772         self._scale.set_default_locators_and_formatters(self)
#     773
#     774         self.isDefault_majloc = True
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/scale.py in set_default_locators_and_formatters(self, axis)
#      71         linear scaling.
#      72         """
# ---> 73         axis.set_major_locator(AutoLocator())
#      74         axis.set_major_formatter(ScalarFormatter())
#      75         axis.set_minor_formatter(NullFormatter())
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/ticker.py in __init__(self)
#    2502             nbins = 'auto'
#    2503             steps = [1, 2, 2.5, 5, 10]
# -> 2504         MaxNLocator.__init__(self, nbins=nbins, steps=steps)
#    2505
#    2506
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/ticker.py in __init__(self, *args, **kwargs)
#    1842
#    1843         """
# -> 1844         if args:
#    1845             kwargs['nbins'] = args[0]
#    1846             if len(args) > 1:
#
# KeyboardInterrupt:
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x11af4db70> (for post_execute):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in post_execute()
#     147             def post_execute():
#     148                 if matplotlib.is_interactive():
# --> 149                     draw_all()
#     150
#     151             # IPython >= 2
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/_pylab_helpers.py in draw_all(cls, force)
#     134         for f_mgr in cls.get_all_fig_managers():
#     135             if force or f_mgr.canvas.figure.stale:
# --> 136                 f_mgr.canvas.draw_idle()
#     137
#     138 atexit.register(Gcf.destroy_all)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    2053         if not self._is_idle_drawing:
#    2054             with self._idle_draw_cntx():
# -> 2055                 self.draw(*args, **kwargs)
#    2056
#    2057     def draw_cursor(self, event):
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     427         Draw the figure using the renderer
#     428         """
# --> 429         self.renderer = self.get_renderer(cleared=True)
#     430         # acquire a lock on the shared font cache
#     431         RendererAgg.lock.acquire()
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in get_renderer(self, cleared)
#     452
#     453         if need_new_renderer:
# --> 454             self.renderer = RendererAgg(w, h, self.figure.dpi)
#     455             self._lastKey = key
#     456         elif cleared:
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in __init__(self, width, height, dpi)
#      99         self.width = width
#     100         self.height = height
# --> 101         self._renderer = _RendererAgg(int(width), int(height), dpi)
#     102         self._filter_renderers = []
#     103
#
# ValueError: Image size of 144288x9936 pixels is too large. It must be less than 2^16 in each direction.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     239
#     240     if 'png' in formats:
# --> 241         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     242     if 'retina' in formats or 'png2x' in formats:
#     243         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     123
#     124     bytes_io = BytesIO()
# --> 125     fig.canvas.print_figure(bytes_io, **kw)
#     126     data = bytes_io.getvalue()
#     127     if fmt == 'svg':
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2210                     orientation=orientation,
#    2211                     dryrun=True,
# -> 2212                     **kwargs)
#    2213                 renderer = self.figure._cachedRenderer
#    2214                 bbox_inches = self.figure.get_tightbbox(renderer)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     515
#     516     def print_png(self, filename_or_obj, *args, **kwargs):
# --> 517         FigureCanvasAgg.draw(self)
#     518         renderer = self.get_renderer()
#     519         original_dpi = renderer.dpi
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     427         Draw the figure using the renderer
#     428         """
# --> 429         self.renderer = self.get_renderer(cleared=True)
#     430         # acquire a lock on the shared font cache
#     431         RendererAgg.lock.acquire()
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in get_renderer(self, cleared)
#     452
#     453         if need_new_renderer:
# --> 454             self.renderer = RendererAgg(w, h, self.figure.dpi)
#     455             self._lastKey = key
#     456         elif cleared:
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in __init__(self, width, height, dpi)
#      99         self.width = width
#     100         self.height = height
# --> 101         self._renderer = _RendererAgg(int(width), int(height), dpi)
#     102         self._filter_renderers = []
#     103
#
# ValueError: Image size of 144288x9936 pixels is too large. It must be less than 2^16 in each direction.

# %%
# sns.set(style="darkgrid")

# g = sns.FacetGrid(df, row="State", col="Incident Date", margin_titles=True)
# bins = np.linspace(0, 60, 13)
# g.map(plt.hist, "# Injured", color="steelblue", bins=bins)

# %%
# sns.set(style="darkgrid")

# g = sns.FacetGrid(df, row="State", col="Incident Date", margin_titles=True)
# bins = np.linspace(0, 60, 13)
# g.map(plt.hist, "# Killed", color="steelblue", bins=bins)

# %%
sns.despine(f, left=True, bottom=True)
sns.scatterplot(x="State", y="# Casualties",
                hue="# Injured", size="# Killed",
                palette="ch:r=-.2,d=.3_r",
                hue_order='State',
                sizes=(1, 8), linewidth=0,
                data=df, ax=ax)
