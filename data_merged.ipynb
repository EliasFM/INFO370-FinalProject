# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns # for visualiation
from datetime import datetime

# %%
# combined mass shooting data from 13-18
mass_shoot_13_18 = pd.read_csv('./data/mass_shooting_data_13_18.csv')
df= mass_shoot_13_18
df = df.drop(['Operations'], axis=1)

# %%
mass = df

# %%
df = pd.read_csv('./data/gunsales_population.csv')

# %%
mass.head()
# Out:
#        Incident Date       State City Or County                     Address  \
# 0  December 31, 2013    New York       Brooklyn             60 Glenmore Ave
# 1  December 28, 2013     Alabama     Montgomery            954 Highland Ave
# 2  December 26, 2013   Louisiana        Slidell               2144 First St
# 3  December 26, 2013   Louisiana       Lockport                313 Tenth St
# 4  December 25, 2013  New Jersey      Irvington  Nye Avenue and 21st Street
#
#    # Killed  # Injured
# 0         0          6
# 1         3          5
# 2         2          6
# 3         3          3
# 4         3          2

# %%
df.head()
# Out:
#    Unnamed: 0  year          state   population  admin   handgun  long_gun  \
# 0           0  2013  United States  316234505.0  267.0  881038.0  788328.0
# 1           1  2013  United States  316234505.0  375.0  770872.0  703223.0
# 2           2  2013  United States  316234505.0  376.0  683266.0  700873.0
# 3           3  2013  United States  316234505.0  665.0  533674.0  554003.0
# 4           4  2013  United States  316234505.0  619.0  445522.0  436674.0
#
#    month  multiple    other    permit     totals
# 0      1   31029.0  26137.0  693076.0  2483230.0
# 1      2   31163.0  22709.0  664252.0  2298561.0
# 2      3   23878.0  23817.0  695386.0  2197116.0
# 3      4   18624.0  21136.0  517224.0  1702455.0
# 4      5   16057.0  15605.0  449993.0  1424450.0

# %%
mass.columns = ['Date','state','city','Address','killed','injured']

# %%
df=df.drop('Unnamed: 0',axis=1)

# %%
mass = mass.drop('Address',axis=1)

# %%
mass['year']=pd.DatetimeIndex(mass['Date']).year

# %%
mass['month']=pd.DatetimeIndex(mass['Date']).month

# %%
mass = mass.drop('Date',axis=1)

# %%
by_shootings = df.merge(mass)

# %%
by_shootings.to_csv('./data/gunsales_population_by_shootings.csv',index=False)

# %%
mass_grouped = mass.groupby(['state','year','month'])['killed','injured'].agg(['sum','count']).reset_index()

# %%
mass_grouped
# Out:
#               state  year month killed       injured
#                                    sum count     sum count
# 0           Alabama  2013     7      0     1       4     1
# 1           Alabama  2013    12      3     1       5     1
# 2           Alabama  2014     1      0     1       5     1
# 3           Alabama  2014     6      1     1       4     1
# 4           Alabama  2015     4      0     1       5     1
# 5           Alabama  2015     5      1     1       3     1
# 6           Alabama  2015    11      3     1       1     1
# 7           Alabama  2015    12      0     1       4     1
# 8           Alabama  2016     2      1     2       8     2
# 9           Alabama  2016     3      2     1       2     1
# 10          Alabama  2016     4      4     4      13     4
# 11          Alabama  2016     5      2     2       7     2
# 12          Alabama  2016     8      6     3      11     3
# 13          Alabama  2016    10      0     1       5     1
# ...

# %%
df = df.merge(mass_grouped)
# Out:
# C:\Users\Elias\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py:544: UserWarning: merging between different levels can give an unintended result (1 levels on the left, 2 on the right)
#   warnings.warn(msg, UserWarning)
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# <ipython-input-140-eeea0426a4f5> in <module>()
# ----> 1 df = df.merge(mass_grouped)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    6387                      right_on=right_on, left_index=left_index,
#    6388                      right_index=right_index, sort=sort, suffixes=suffixes,
# -> 6389                      copy=copy, indicator=indicator, validate=validate)
#    6390
#    6391     def round(self, decimals=0, *args, **kwargs):
#
# ...

# %%
df.admin = 100000 * df.admin/df.population

# %%
df.handgun = 100000 * df.handgun/df.population

# %%
df.long_gun = 100000 * df.long_gun/df.population

# %%
df.multiple = 100000 * df.multiple/df.population

# %%
df.other = 100000 * df.other/df.population

# %%
df.permit = 100000 * df.permit/df.population

# %%
df.totals = 100000 * df.totals/df.population

# %%
df.killed = 100000 * df.killed/df.population

# %%
df.injured = 100000 * df.injured/df.population

# %%
df
# Out:
#      year                 state  population     admin     handgun    long_gun  \
# 0    2013               Alabama   4827660.0  0.000000  418.132180  632.252478
# 1    2013               Alabama   4827660.0  0.000000  249.769039  249.334046
# 2    2013               Arizona   6616124.0  0.000000  151.584221  151.977200
# 3    2013               Arizona   6616124.0  0.000000  131.784108  117.138071
# 4    2013               Arizona   6616124.0  0.000000  144.087384  110.638797
# 5    2013               Arizona   6616124.0  0.000000  177.959180  130.741201
# 6    2013            California  38347383.0  0.000000   81.264998  113.994741
# 7    2013            California  38347383.0  0.000000   80.039360   98.609076
# 8    2013            California  38347383.0  0.000000   71.509443  101.967845
# 9    2013            California  38347383.0  0.005215   80.892091  104.241794
# 10   2013            California  38347383.0  0.010431   77.009166   82.310702
# ...

# %%
df.to_csv('./data/shootings_and_sales_per_pop.csv',index=False)
